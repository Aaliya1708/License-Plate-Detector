# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import cv2
from PIL import Image
import os
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1)
        self.pool = nn.MaxPool2d((2,2), stride=(1,1))
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(25600, 1024)
        self.fc2 = nn.Linear(1024,128)
        self.fc3 = nn.Linear(128, 36)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = x.view(-1, 25600)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
net = Net()

# %%
net
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(1, 1), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=25600, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=36, bias=True)
# )

# %%
class CharDataset(Dataset):
    def __init__(self, root_dir,transform=None,preprocess=None):
        self.root_dir = root_dir
        self.classes = sorted(os.listdir(root_dir))
        self.arr = []
        for class_name in self.classes:
            for ele in os.listdir("/".join([root_dir, class_name])):
                self.arr.append(["/".join([root_dir, class_name,ele]), class_name])
        self.arr = np.array(self.arr)
        np.random.shuffle(self.arr)
        self.transform = transform
        self.preprocess = preprocess
        
    def __len__(self):
        return len(self.arr)
    
    def __getitem__(self, index):
        img = cv2.imread(self.arr[index,0])
        if self.preprocess is not None:
            img = self.preprocess(img)
            
        if self.transform is not None:
            img = self.transform(img)
        
        y_label = torch.tensor((self.classes.index(self.arr[index,1])))
        
        return (img, y_label)

# %%
transform = transforms.Compose(
    [
        transforms.Resize((32,32)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]
)

# %%
def preprocess(img,pad=True):
    m = max(img.shape[0:2])
    if pad:
        m+=5
    img = cv2.copyMakeBorder(img, int((m-img.shape[0])/2),  
                                    int((m-img.shape[0])/2),  
                                    int((m-img.shape[1])/2),  
                                    int((m-img.shape[1])/2),
                                    cv2.BORDER_REPLICATE)
    img = cv2.resize(img, (32,32))
    return Image.fromarray(img)

# %%
dataset = CharDataset("char_recog_data", transform, preprocess)
train_set, validation_set = torch.utils.data.random_split(dataset, [12000,2075], )

train_loader = DataLoader(dataset=train_set, shuffle=True, batch_size=32, num_workers=1,pin_memory=True)

validation_loader = DataLoader(dataset=validation_set, shuffle=True, batch_size=32, num_workers=1,pin_memory=True)

# %%
device = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
def check_accuracy(loader,model):
    accs = 0 
    cnt = 0
    with torch.no_grad():
        for x, y in loader:
            cnt += 1
            x = x.to(device=device)
            y = y.to(device=device)

            scores = model(x)
            y_pred_softmax = torch.log_softmax(scores, dim = 1)
            _, y_pred = torch.max(y_pred_softmax,dim=-1)
            correct_pred = (y==y_pred).float()
            acc = correct_pred.sum() / len(correct_pred)
            accs += acc
        accs/=cnt
    print("Accuracy:",accs)

# %%
def train():
    net = Net().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    for param_tensor in net.state_dict():
        print(param_tensor, "\t", net.state_dict()[param_tensor].size())
    
    dataset = CharDataset("char_recog_data_1",  transform, preprocess)
    train_set, validation_set = torch.utils.data.random_split(dataset, [16000,3424])

    trainloader = DataLoader(dataset=train_set, shuffle=True, batch_size=32, num_workers=1,pin_memory=True)

    validation_loader = DataLoader(dataset=validation_set, shuffle=True, batch_size=32, num_workers=1,pin_memory=True)
    
    for epoch in range(25):
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            output = net(inputs)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if i%100 == 99:
                print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
        print("On Training Set")
        check_accuracy(trainloader, net)
        print("On Validation Set")
        check_accuracy(validation_loader,net)
    
    print("Finished training")
    torch.save(net.state_dict(), "character_recog_up.pt")

# %%
train()
# Out:
# conv1.weight 	 torch.Size([32, 3, 5, 5])
# conv1.bias 	 torch.Size([32])
# conv2.weight 	 torch.Size([64, 32, 5, 5])
# conv2.bias 	 torch.Size([64])
# conv3.weight 	 torch.Size([64, 64, 3, 3])
# conv3.bias 	 torch.Size([64])
# fc1.weight 	 torch.Size([1024, 25600])
# fc1.bias 	 torch.Size([1024])
# fc2.weight 	 torch.Size([128, 1024])
# fc2.bias 	 torch.Size([128])
# fc3.weight 	 torch.Size([36, 128])
# fc3.bias 	 torch.Size([36])
# [1,   100] loss: 2.960
# [1,   200] loss: 1.534
# [1,   300] loss: 0.968
# [1,   400] loss: 0.755
# [1,   500] loss: 0.629
# On Training Set
# Accuracy: tensor(0.8434, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.8254, device='cuda:0')
# [2,   100] loss: 0.468
# [2,   200] loss: 0.451
# [2,   300] loss: 0.394
# [2,   400] loss: 0.388
# [2,   500] loss: 0.354
# On Training Set
# Accuracy: tensor(0.9233, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9060, device='cuda:0')
# [3,   100] loss: 0.295
# [3,   200] loss: 0.289
# [3,   300] loss: 0.286
# [3,   400] loss: 0.211
# [3,   500] loss: 0.255
# On Training Set
# Accuracy: tensor(0.9439, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9138, device='cuda:0')
# [4,   100] loss: 0.214
# [4,   200] loss: 0.213
# [4,   300] loss: 0.189
# [4,   400] loss: 0.209
# [4,   500] loss: 0.203
# On Training Set
# Accuracy: tensor(0.9539, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9238, device='cuda:0')
# [5,   100] loss: 0.149
# [5,   200] loss: 0.164
# [5,   300] loss: 0.187
# [5,   400] loss: 0.191
# [5,   500] loss: 0.194
# On Training Set
# Accuracy: tensor(0.9582, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9276, device='cuda:0')
# [6,   100] loss: 0.117
# [6,   200] loss: 0.119
# [6,   300] loss: 0.132
# [6,   400] loss: 0.146
# [6,   500] loss: 0.157
# On Training Set
# Accuracy: tensor(0.9671, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9299, device='cuda:0')
# [7,   100] loss: 0.103
# [7,   200] loss: 0.118
# [7,   300] loss: 0.119
# [7,   400] loss: 0.147
# [7,   500] loss: 0.135
# On Training Set
# Accuracy: tensor(0.9664, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9241, device='cuda:0')
# [8,   100] loss: 0.154
# [8,   200] loss: 0.110
# [8,   300] loss: 0.128
# [8,   400] loss: 0.121
# [8,   500] loss: 0.124
# On Training Set
# Accuracy: tensor(0.9708, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9346, device='cuda:0')
# [9,   100] loss: 0.077
# [9,   200] loss: 0.096
# [9,   300] loss: 0.172
# [9,   400] loss: 0.151
# [9,   500] loss: 0.102
# On Training Set
# Accuracy: tensor(0.9790, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9343, device='cuda:0')
# [10,   100] loss: 0.088
# [10,   200] loss: 0.074
# [10,   300] loss: 0.080
# [10,   400] loss: 0.099
# [10,   500] loss: 0.084
# On Training Set
# Accuracy: tensor(0.9658, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9241, device='cuda:0')
# [11,   100] loss: 0.112
# [11,   200] loss: 0.077
# [11,   300] loss: 0.099
# [11,   400] loss: 0.088
# [11,   500] loss: 0.099
# On Training Set
# Accuracy: tensor(0.9774, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9366, device='cuda:0')
# [12,   100] loss: 0.106
# [12,   200] loss: 0.105
# [12,   300] loss: 0.097
# [12,   400] loss: 0.090
# [12,   500] loss: 0.085
# On Training Set
# Accuracy: tensor(0.9821, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9372, device='cuda:0')
# [13,   100] loss: 0.067
# [13,   200] loss: 0.091
# [13,   300] loss: 0.079
# [13,   400] loss: 0.062
# [13,   500] loss: 0.062
# On Training Set
# Accuracy: tensor(0.9845, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9317, device='cuda:0')
# [14,   100] loss: 0.039
# [14,   200] loss: 0.033
# [14,   300] loss: 0.055
# [14,   400] loss: 0.071
# [14,   500] loss: 0.113
# On Training Set
# Accuracy: tensor(0.9697, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9229, device='cuda:0')
# [15,   100] loss: 0.083
# [15,   200] loss: 0.126
# [15,   300] loss: 0.129
# [15,   400] loss: 0.065
# [15,   500] loss: 0.075
# On Training Set
# Accuracy: tensor(0.9867, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9381, device='cuda:0')
# [16,   100] loss: 0.064
# [16,   200] loss: 0.044
# [16,   300] loss: 0.054
# [16,   400] loss: 0.074
# [16,   500] loss: 0.058
# On Training Set
# Accuracy: tensor(0.9844, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9355, device='cuda:0')
# [17,   100] loss: 0.057
# [17,   200] loss: 0.069
# [17,   300] loss: 0.080
# [17,   400] loss: 0.045
# [17,   500] loss: 0.083
# On Training Set
# Accuracy: tensor(0.9782, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9232, device='cuda:0')
# [18,   100] loss: 0.055
# [18,   200] loss: 0.050
# [18,   300] loss: 0.071
# [18,   400] loss: 0.132
# [18,   500] loss: 0.064
# On Training Set
# Accuracy: tensor(0.9868, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9357, device='cuda:0')
# [19,   100] loss: 0.027
# [19,   200] loss: 0.050
# [19,   300] loss: 0.044
# [19,   400] loss: 0.034
# [19,   500] loss: 0.044
# On Training Set
# Accuracy: tensor(0.9871, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9393, device='cuda:0')
# [20,   100] loss: 0.067
# [20,   200] loss: 0.122
# [20,   300] loss: 0.090
# [20,   400] loss: 0.099
# [20,   500] loss: 0.071
# On Training Set
# Accuracy: tensor(0.9903, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9407, device='cuda:0')
# [21,   100] loss: 0.039
# [21,   200] loss: 0.098
# [21,   300] loss: 0.062
# [21,   400] loss: 0.052
# [21,   500] loss: 0.106
# On Training Set
# Accuracy: tensor(0.9813, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9340, device='cuda:0')
# [22,   100] loss: 0.051
# [22,   200] loss: 0.039
# [22,   300] loss: 0.080
# [22,   400] loss: 0.061
# [22,   500] loss: 0.056
# On Training Set
# Accuracy: tensor(0.9872, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9375, device='cuda:0')
# [23,   100] loss: 0.042
# [23,   200] loss: 0.103
# [23,   300] loss: 0.086
# [23,   400] loss: 0.059
# [23,   500] loss: 0.040
# On Training Set
# Accuracy: tensor(0.9934, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9390, device='cuda:0')
# [24,   100] loss: 0.020
# [24,   200] loss: 0.028
# [24,   300] loss: 0.041
# [24,   400] loss: 0.028
# [24,   500] loss: 0.052
# On Training Set
# Accuracy: tensor(0.9879, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9322, device='cuda:0')
# [25,   100] loss: 0.055
# [25,   200] loss: 0.051
# [25,   300] loss: 0.038
# [25,   400] loss: 0.059
# [25,   500] loss: 0.058
# On Training Set
# Accuracy: tensor(0.9886, device='cuda:0')
# On Validation Set
# Accuracy: tensor(0.9395, device='cuda:0')
# Finished training
